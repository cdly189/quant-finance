# %% [markdown]
# ### Quantnet Goldman Sach Suggested Reading List

# %%
from bs4 import BeautifulSoup
import requests

source = requests.get('https://quantnet.com/threads/the-goldman-sachs-suggested-reading-list.4916/').text

soup = BeautifulSoup(source,'lxml')


for name in soup.find_all('a', class_='link link--external'):
    print(name.text)
# Out:
# The Five Great Myths About China and The World
# Exploring General Equilibrium
# Business Cycles and Equilibrium
# Old Girls' Network: Insider Advice for Women Building Businesses in a Man's World
# Goldman Sachs : The Culture of Success
# Beginning the Journey: China the United States and the WTO
# Global Aging and Financial Markets: Hard Landings Ahead
# The Boundaryless Organization: Breaking the Chains of Organization Structure, Revised and Updated
# The GE Work-Out : How to Implement GE's Revolutionary Method for Busting Bureaucracy & Attacking Organizational Proble
# The Practice of Risk Management
# Foundations for Financial Economics
# Markets, Mobs & Mayhem: How to Profit From the Madness of Crowds
# Adam Smith and the Origins of American Enterprise
# Wealth Creators : The Rise of Today's New Rich and Super-Rich
# The Global Bankers
# High Finance in the Euro-Zone: Competing in the New European Capital Market
# ...
